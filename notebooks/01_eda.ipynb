# %% [markdown]
# # Exploratory data analysis
#
# This notebook examines class imbalance and pre-accident covariates only. Reusable transformations live in `src/`.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()))
from src.data import load_raw
from src.features import add_time_features
df = add_time_features(load_raw())
df['Accident_Severity'].value_counts(normalize=True).sort_index()

# %% [markdown]
# ## Leakage contract
#
# Collision outcomes and fields learned only after impact are removed in `src.data.DROP_COLUMNS` before modeling.
