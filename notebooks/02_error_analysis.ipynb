# %% [markdown]
# # Error analysis
#
# The reproducible source of truth is `scripts/generate_error_analysis.py`. This notebook is a lightweight workspace for exploring its generated outputs.

# %%
import pandas as pd
comparison = pd.read_csv('../reports/results/model_comparison.csv')
comparison.sort_values('macro_f1', ascending=False)

# %% [markdown]
# See `reports/modeling_report.md` for the confusion matrices, Fatal precision–recall and threshold analysis, global and Fatal-specific SHAP plots, and feature-distribution overlaps.
